# %%
# Write a python program to display all the header tags from wikipedia.org and make data frame.

# importing libraries

from bs4 import BeautifulSoup
import requests

# %%
respose_req = requests.get('https://www.wikipedia.org/')

respose_req
# Out:
# <Response [200]>

# %%
wiki_page = BeautifulSoup(page.content)

wiki_page
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Wikipedia</title>
# <meta content="Wikipedia is a free online encyclopedia, created and edited by volunteers around the world and hosted by the Wikimedia Foundation." name="description"/>
# <script>
# document.documentElement.className = document.documentElement.className.replace( /(^|\s)no-js(\s|$)/, "$1js-enabled$2" );
# </script>
# <meta content="initial-scale=1,user-scalable=yes" name="viewport"/>
# <link href="/static/apple-touch/wikipedia.png" rel="apple-touch-icon"/>
# <link href="/static/favicon/wikipedia.ico" rel="shortcut icon"/>
# <link href="//creativecommons.org/licenses/by-sa/4.0/" rel="license"/>
# <style>
# ...

# %%
# For getting all header

header = []

for i in wiki_page.find_all ('div',class_="central-featured-lang lang1"):
    header.append(i.text)
    
header
# Out:
# ['\n\nEnglish\n6\xa0691\xa0000+ articles\n\n']

# %%
# Write s python program to display list of respected former presidents of India(i.e. Name , Term ofoffice) 
#from https://presidentofindia.nic.in/former-presidents.htm and make data frame.

respose_req = requests.get('https://presidentofindia.nic.in/former-presidents')

respose_req
# Out:
# <Response [200]>

# %%
formar_presidents = BeautifulSoup(respose_req.content)

formar_presidents
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="Drupal 9 (https://www.drupal.org)" name="Generator"/>
# <meta content="width" name="MobileOptimized"/>
# <meta content="true" name="HandheldFriendly"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="/sites/default/files/tiranga_1.png" rel="icon" type="image/png"/>
# <title>Former Presidents of India | President of India</title>
# <link href="/libraries/superfish/css/superfish.css?rziu9l" media="all" rel="stylesheet"/>
# <link href="/core/modules/system/css/components/ajax-progress.module.css?rziu9l" media="all" rel="stylesheet"/>
# <link href="/core/modules/system/css/components/align.module.css?rziu9l" media="all" rel="stylesheet"/>
# <link href="/core/modules/system/css/components/autocomplete-loading.module.css?rziu9l" media="all" rel="stylesheet"/>
# ...

# %%
first_name = formar_presidents.find('div',class_ ="desc-sec")

first_name.text.replace("\n",'')
# Out:
# 'Shri Ram Nath Kovind14th President of India'

# %%
Names = []

for i in formar_presidents.find_all('div',class_="desc-sec"):
    Names.append(i.text.replace("\n",''))

Names
# Out:
# ['Shri Ram Nath Kovind14th President of India',
#  'Shri Pranab Mukherjee13th President of India',
#  'Smt Pratibha Devisingh Patil12th President of India',
#  'DR. A.P.J. Abdul Kalam11th President of India',
#  'Shri K. R. Narayanan10th President of India',
#  'Dr Shankar Dayal Sharma9th  President of India',
#  'Shri R Venkataraman8th President of India',
#  'Giani Zail Singh7th President of India',
#  'Shri Neelam Sanjiva Reddy6th President of India',
#  'Dr. Fakhruddin Ali Ahmed5th President of India',
#  'Shri Varahagiri Venkata Giri4th President of India',
#  'Dr. Zakir Husain3rd President of India',
#  'Dr. Sarvepalli Radhakrishnan2nd President of India',
#  'Dr. Rajendra Prasad1st President of India']

# %%
import pandas as pd

Formar_presidents = pd.DataFrame({'Formar_presidents_Name':Names})

Formar_presidents
# Out:
#                                Formar_presidents_Name
# 0         Shri Ram Nath Kovind14th President of India
# 1        Shri Pranab Mukherjee13th President of India
# 2   Smt Pratibha Devisingh Patil12th President of ...
# 3       DR. A.P.J. Abdul Kalam11th President of India
# 4         Shri K. R. Narayanan10th President of India
# 5      Dr Shankar Dayal Sharma9th  President of India
# 6           Shri R Venkataraman8th President of India
# 7              Giani Zail Singh7th President of India
# 8     Shri Neelam Sanjiva Reddy6th President of India
# 9      Dr. Fakhruddin Ali Ahmed5th President of India
# 10  Shri Varahagiri Venkata Giri4th President of I...
# 11             Dr. Zakir Husain3rd President of India
# 12  Dr. Sarvepalli Radhakrishnan2nd President of I...
# 13          Dr. Rajendra Prasad1st President of India

# %%
# Write a python program to scrape cricket rankings from icc-cricket.com. You have to scrape and make data frame-
# a) Top 10 ODI teams in men’s cricket along with the records for matches, points and rating.
# b) Top 10 ODI Batsmen along with the records of their team andrating.
# c) Top 10 ODI bowlers along with the records of their team andrating.

respose_req = requests.get('https://www.icc-cricket.com/rankings/mens/team-rankings/odi')

respose_req

icc_page = BeautifulSoup(respose_req.content,"html.parser")

icc_page
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta content="ICC Men's ODI Team Rankings | ICC" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official International Cricket Council ranking for One Day International (ODI) cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official International Cricket Council ranking for One Day International (ODI) cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="ICC Men's ODI Team Rankings | ICC" property="og:title"/>
# ...

# %%
# top 10 ODI teams in men’s cricket along with the records for matches, points and rating

# %%
team = []

for i in icc_page.find_all ('span',class_="u-hide-phablet"):
    team.append(i.text)
    
team
# Out:
# ['Australia',
#  'Pakistan',
#  'India',
#  'New Zealand',
#  'England',
#  'South Africa',
#  'Bangladesh',
#  'Afghanistan',
#  'Sri Lanka',
#  'West Indies',
#  'Zimbabwe',
#  'Scotland',
#  'Ireland',
#  'Netherlands',
#  'Nepal',
#  'Namibia',
#  'United States',
#  'Oman',
#  'UAE']

# %%
for_aus = icc_page.find('td', class_ = "rankings-block__banner--matches")

for_aus.text
# Out:
# '23'

# %%
first_matches = []
matches = []

for i in icc_page.find_all ('td', class_='rankings-block__banner--matches'):
    first_matches.append(i.text)
for x in icc_page.find_all('td', class_="table-body__cell u-center-text"):
    matches.append(x.text)
matches
# Out:
# ['20',
#  '2,316',
#  '36',
#  '4,081',
#  '27',
#  '2,806',
#  '24',
#  '2,426',
#  '19',
#  '1,910',
#  '28',
#  '2,661',
#  '16',
#  '1,404',
#  '32',
#  '2,794',
#  '38',
#  '2,582',
#  '30',
#  '1,641',
#  '33',
#  '1,662',
#  '24',
#  '1,052',
#  '28',
#  '1,044',
#  '40',
#  '1,396',
#  '28',
#  '813',
#  '31',
#  '808',
#  '24',
#  '525',
#  '41',
#  '617']

# %%
points = []

for i in icc_page.find_all('td',class_ ="rankings-block__banner--points"):
    points.append(i.text)
    
print(points)
# Out:
# ['2,714']

# %%
RATING = []

for i in icc_page.find_all('td',class_="rankings-block__banner--rating u-text-right"):
        RATING.append(i.text.replace('\n                          ',''))
    
print(RATING)
# Out:
# ['  118  \n\n']

# %%
#Top 10 ODI Batsmen along with the records of their team andrating.

url = "https://www.icc-cricket.com/rankings/mens/player-rankings/odi/batting"
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.content, "html.parser")

# %%
players = []
ratings = []

for player in soup.find_all('td', class_='table-body__cell name'):
    players.append(player.find('a').text)
      
for rating in soup.find_all('td', class_='table-body__cell u-text-right rating'):
    ratings.append(rating.text)

# %%
batting_data = {
    "Player": players[:10],
    "Rating": ratings[:10]
}

# %%
print(len('Player'))
print(len('Team'))
print(len('Rating'))
# Out:
# 6
# 4
# 6

# %%
batting_df = pd.DataFrame(batting_data)

print(batting_df)
# Out:
# Empty DataFrame
# Columns: [Player, Rating]
# Index: []

# %%
# c) Top 10 ODI bowlers along with the records of their team andrating.

url = 'https://www.icc-cricket.com/rankings/mens/player-rankings/odi/bowling'
response = requests.get(url)
response

soup = BeautifulSoup(response.content, "html.parser")

players = []
teams = []
ratings = []

for player in soup.find_all('td', class_='table-body__cell name'):
    players.append(player.find('a').text)
    
for team in soup.find_all('span', class_='table-body__logo-text'):
    teams.append(team.text)
    
for rating in soup.find_all('td', class_='table-body__cell u-text-right rating'):
    ratings.append(rating.text)
    

    
bowling_data = {
    "Player": players[:10],
    "Team": teams[:10],
    "Rating": ratings[:10]
}

bowling_df = pd.DataFrame(bowling_data)

print(bowling_df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [102], in <cell line: 30>()
#      20     ratings.append(rating.text)
#      24 bowling_data = {
#      25     "Player": players[:10],
#      26     "Team": teams[:10],
#      27     "Rating": ratings[:10]
#      28 }
# ---> 30 bowling_df = pd.DataFrame(bowling_data)
#      32 print(bowling_df)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:636, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     630     mgr = self._init_mgr(
#     631         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     632     )
#     634 elif isinstance(data, dict):
#     635     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 636     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     637 elif isinstance(data, ma.MaskedArray):
# ...

# %%
# 4) Write a python program to scrape cricket rankings from icc-cricket.com. You have to scrape and make data frame-
# a) Top 10 ODI teams in women’s cricket along with the records for matches, points and rating.
# b) Top 10 women’s ODI Batting players along with the records of their team and rating.
# c) Top 10 women’s ODI all-rounder along with the records of their team and rating.

#a) Top 10 ODI teams in women’s cricket along with the records for matches, points and rating.

url = 'https://www.icc-cricket.com/rankings/mens/team-rankings/t20i'
response = requests.get(url)
response

soup = BeautifulSoup(response.content, "html.parser")


Team = []
Matches_women = []

for i in icc_page.find_all ('span',class_="u-hide-phablet"):
    Team.append(i.text)
for i in icc_page.find_all ('td',class_="rankings-block__banner--matches"):
    Matches_women.append(i.text)
    
print(Team)
print(Matches_women)
# Out:
# ['Australia', 'Pakistan', 'India', 'New Zealand', 'England', 'South Africa', 'Bangladesh', 'Afghanistan', 'Sri Lanka', 'West Indies', 'Zimbabwe', 'Scotland', 'Ireland', 'Netherlands', 'Nepal', 'Namibia', 'United States', 'Oman', 'UAE']
# ['23']

# %%
# Write a python program to scrape mentioned news details from https://www.cnbc.com/world/?region=world and make data frame-
# i) Headline
# ii) Time
# iii) News Link


news_responce = requests.get('https://www.cnbc.com/world/')
news_responce
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(news_responce.content)
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
Headlines = []

for i in soup.find_all('div', class_="Card-titleContainer"):
    Headlines.append(i.text)
    
print(Headlines)
# Out:
# ['Nasdaq falls a fourth day in a row, notches longest weekly losing streak since December: Live...', "Can expensive, American-made weapons like F-16s turn the tide in Ukraine's war against Russia?", "Here's why Ukraine wants more big ticket Western-made weapons", 'U.S. approves shipments of F-16s to Ukraine in major gain for Kiev', 'Ukraine to receive F-16 jets from Denmark and Netherlands; Russia reports Moscow drone attack', 'Ukraine sees no hope for F-16s this year; Naftogaz CEO wants EU discussions on Russia gas transit', 'A multitrillion-dollar carbon bubble? Climate chief warns world leaders over fossil fuel plans', 'Moving toward low carbon steel is a matter of survival: Gunung Raja Paksi', 'We share the same vision as Fortescue Future Industries: Gunung Raja Paksi', 'Business is war, and we go to war every day: Gunung Raja Paksi', 'Offshore wind turbine catches fire off east coast of Britain', 'Southeast Asia turns to alternative meats as fight against climate change ramps up
# ...

# %%
Time = []

for i in soup.find_all('time', class_="LatestNews-timestamp"):
    Time.append(i.text)
    
print(Time)
# Out:
# ['22 Min Ago', '40 Min Ago', '44 Min Ago', '19 Hours Ago', '20 Hours Ago', '21 Hours Ago', '23 Hours Ago', '23 Hours Ago', '23 Hours Ago', '23 Hours Ago', '24 Hours Ago', '24 Hours Ago', '24 Hours Ago', 'August 19, 2023', 'August 19, 2023', 'August 19, 2023', 'August 19, 2023', 'August 19, 2023', 'August 19, 2023', 'August 18, 2023', 'August 18, 2023', 'August 18, 2023', 'August 18, 2023', 'August 18, 2023', 'August 18, 2023', 'August 18, 2023', 'August 18, 2023', 'August 18, 2023', 'August 18, 2023', 'August 18, 2023']

# %%
print(len(Headlines))
print(len(Time))
# Out:
# 26
# 30

# %%
import pandas as pd


data = {
    "Headlines": Headlines[:10],
    "Time": Time[:10]
}

news_df = pd.DataFrame(data)

news_df
# Out:
#                                            Headlines          Time
# 0  Nasdaq falls a fourth day in a row, notches lo...    22 Min Ago
# 1  Can expensive, American-made weapons like F-16...    40 Min Ago
# 2  Here's why Ukraine wants more big ticket Weste...    44 Min Ago
# 3  U.S. approves shipments of F-16s to Ukraine in...  19 Hours Ago
# 4  Ukraine to receive F-16 jets from Denmark and ...  20 Hours Ago
# 5  Ukraine sees no hope for F-16s this year; Naft...  21 Hours Ago
# 6  A multitrillion-dollar carbon bubble? Climate ...  23 Hours Ago
# 7  Moving toward low carbon steel is a matter of ...  23 Hours Ago
# 8  We share the same vision as Fortescue Future I...  23 Hours Ago
# 9  Business is war, and we go to war every day: G...  23 Hours Ago

# %%
# Write a python program to scrape the details of most downloaded articles from AI in last 90 days.https://www.journals.elsevier.com/artificial-intelligence/most-downloaded-articles Scrape below mentioned details and make data frame-
# i) Paper Title
# ii) Authors
# iii) Published Date
# iv) Paper URL

AI_responce = requests.get('https://www.journals.elsevier.com/artificial-intelligence/most-downloaded-articles')
AI_responce

soup = BeautifulSoup(AI_responce.content)
soup



Paper_Title = []


for i in soup.find_all('h2', class_="sc-1qrq3sd-1 gRGSUS sc-1nmom32-0 sc-1nmom32-1 btcbYu goSKRg"):
    Paper_Title.append(i.text)

    
print(Paper_Title)
# Out:
# ['Reward is enough', 'Explanation in artificial intelligence: Insights from the social sciences', 'Creativity and artificial intelligence', 'Conflict-based search for optimal multi-agent pathfinding', 'Knowledge graphs as tools for explainable machine learning: A survey', 'Law and logic: A review from an argumentation perspective', 'Between MDPs and semi-MDPs: A framework for temporal abstraction in reinforcement learning', 'Explaining individual predictions when features are dependent: More accurate approximations to Shapley values', 'Multiple object tracking: A literature review', 'A survey of inverse reinforcement learning: Challenges, methods and progress', 'Evaluating XAI: A comparison of rule-based and example-based explanations', 'Explainable AI tools for legal reasoning about cases: A study on the European Court of Human Rights', 'Hard choices in artificial intelligence', 'Assessing the communication gap between AI models and healthcare professionals: Explainability, utility 
# ...

# %%
Authors = []

for i in soup.find_all('span', class_="sc-1w3fpd7-0 dnCnAO"):
    Authors.append(i.text)
    
print(Authors)
# Out:
# ['David Silver, Satinder Singh, Doina Precup, Richard S. Sutton ', 'Tim Miller ', 'Margaret A. Boden ', 'Guni Sharon, Roni Stern, Ariel Felner, Nathan R. Sturtevant ', 'Ilaria Tiddi, Stefan Schlobach ', 'Henry Prakken, Giovanni Sartor ', 'Richard S. Sutton, Doina Precup, Satinder Singh ', 'Kjersti Aas, Martin Jullum, Anders Løland ', 'Wenhan Luo, Junliang Xing and 4 more', 'Saurabh Arora, Prashant Doshi ', 'Jasper van der Waa, Elisabeth Nieuwburg, Anita Cremers, Mark Neerincx ', 'Joe Collenette, Katie Atkinson, Trevor Bench-Capon ', 'Roel Dobbe, Thomas Krendl Gilbert, Yonatan Mintz ', 'Oskar Wysocki, Jessica Katharine Davies and 5 more', 'Eoin M. Kenny, Courtney Ford, Molly Quinn, Mark T. Keane ', 'Nolan Bard, Jakob N. Foerster and 13 more', 'Ron Kohavi, George H. John ', 'Séverin Lemaignan, Mathieu Warnier and 3 more', 'Tomáš Kliegr, Štěpán Bahník, Johannes Fürnkranz ', 'Luigia Carlucci Aiello ', 'Patrick Lin, Keith Abney, George Bekey ', 'W. Bradley Knox, Alessandro Allievi and 3 m
# ...

# %%
Published_Date = []

for i in soup.find_all('span', class_="sc-1thf9ly-2 dvggWt"):
    Published_Date.append(i.text)
    
print(Published_Date)
# Out:
# ['October 2021', 'February 2019', 'August 1998', 'February 2015', 'January 2022', 'October 2015', 'August 1999', 'September 2021', 'April 2021', 'August 2021', 'February 2021', 'April 2023', 'November 2021', 'March 2023', 'May 2021', 'March 2020', 'December 1997', 'June 2017', 'June 2021', 'June 2016', 'April 2011', 'March 2023', 'May 1998', 'July 2021']

# %%
data = {
    "Paper_Title": Paper_Title[:10],
    "Authors": Authors[:10],
    "Published_Date": Published_Date[:10]
}

papers_df = pd.DataFrame(data)

papers_df
# Out:
#                                          Paper_Title  \
# 0                                   Reward is enough
# 1  Explanation in artificial intelligence: Insigh...
# 2             Creativity and artificial intelligence
# 3  Conflict-based search for optimal multi-agent ...
# 4  Knowledge graphs as tools for explainable mach...
# 5  Law and logic: A review from an argumentation ...
# 6  Between MDPs and semi-MDPs: A framework for te...
# 7  Explaining individual predictions when feature...
# 8      Multiple object tracking: A literature review
# 9  A survey of inverse reinforcement learning: Ch...
#
#                                              Authors  Published_Date
# 0  David Silver, Satinder Singh, Doina Precup, Ri...    October 2021
# 1                                        Tim Miller    February 2019
# 2                                 Margaret A. Boden      August 1998
# 3  Guni Sharon, Roni Stern, Ariel Felner, Nathan ...   February 2015
# ...

# %%
# 7) Write a python program to scrape mentioned details from dineout.co.in and make data frame-
# i) Restaurant name
# ii) Cuisine
# iii) Location
# iv) Ratings
# v) Image URL


page = requests.get('https://www.dineout.co.in/delhi-restaurants/buffet-special')

page

soup = BeautifulSoup(page.content)

soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head><meta charset="utf-8"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/><link href="/manifest.json" rel="manifest"/><style type="text/css">
#             @font-face {
#                 font-family: 'dineicon';
#                 src:  url('/fonts/dineicon.eot');
#                 src:  url('/fonts/dineicon.eot#iefix') format('embedded-opentype'),
#                 url('/fonts/dineicon.ttf') format('truetype'),
#                 url('/fonts/dineicon.woff') format('woff'),
#                 url('/fonts/dineicon.svg#dineicon') format('svg');
#                 font-weight: normal;
# 				font-style: normal;
# 				font-display: swap;
#             }
#             .hide {
#                 display: none !important;
#             }
#             .async-hide{
#                 opacity: inherit !important;
#             }
# ...

# %%
Restaurant_name = []

for i in soup.find_all ('div',class_="restnt-info cursor"):
    Restaurant_name.append(i.text)
    
Restaurant_name
# Out:
# ['Castle BarbequeConnaught Place, Central Delhi',
#  'Cafe KnoshThe Leela Ambience Convention Hotel,Shahdara, East Delhi',
#  "Castle's BarbequePacific Mall,Tagore Garden, West Delhi",
#  'India GrillHilton Garden Inn,Saket, South Delhi',
#  'The Barbeque CompanyGardens Galleria,Sector 38A, Noida',
#  'Delhi BarbequeTaurus Sarovar Portico,Mahipalpur, South Delhi',
#  'The Monarch - Bar Be Que VillageIndirapuram Habitat Centre,Indirapuram, Ghaziabad',
#  'The Barbeque TimesM2K Corporate Park,Sector 51, Gurgaon',
#  'Indian Grill RoomSuncity Business Tower,Golf Course Road, Gurgaon']

# %%
Cuisine = []

for i in soup.find_all ('div',class_="restnt-loc ellipsis"):
    Cuisine.append(i.text)
    
Cuisine
# Out:
# ['Connaught Place, Central Delhi',
#  'The Leela Ambience Convention Hotel,Shahdara, East Delhi',
#  'Pacific Mall,Tagore Garden, West Delhi',
#  'Hilton Garden Inn,Saket, South Delhi',
#  'Gardens Galleria,Sector 38A, Noida',
#  'Taurus Sarovar Portico,Mahipalpur, South Delhi',
#  'Indirapuram Habitat Centre,Indirapuram, Ghaziabad',
#  'M2K Corporate Park,Sector 51, Gurgaon',
#  'Suncity Business Tower,Golf Course Road, Gurgaon']

# %%
Ratings = []

for i in soup.find_all ('div',class_="restnt-rating rating-4"):
    Ratings.append(i.text)
    
Ratings
# Out:
# ['4', '4.3', '3.9', '3.9', '3.9', '3.7', '3.8', '4.1', '4.3']

# %%
Image_URL = []

for i in soup.find_all ('img',class_="no-img"):
    Image_URL.append(i['data-src'])
    
Image_URL
# Out:
# ['https://im1.dineout.co.in/images/uploads/restaurant/sharpen/8/k/b/p86792-16062953735fbe1f4d3fb7e.jpg?tr=tr:n-medium',
#  'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/4/p/m/p406-15438184745c04ccea491bc.jpg?tr=tr:n-medium',
#  'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/3/j/o/p38113-15959192065f1fcb666130c.jpg?tr=tr:n-medium',
#  'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/2/v/t/p2687-1482477169585cce712b90f.jpg?tr=tr:n-medium',
#  'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/7/p/k/p79307-16051787755fad1597f2bf9.jpg?tr=tr:n-medium',
#  'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/5/d/i/p52501-1661855212630de5eceb6d2.jpg?tr=tr:n-medium',
#  'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/3/n/o/p34822-15599107305cfa594a13c24.jpg?tr=tr:n-medium',
#  'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/1/u/r/p106428-166073786162fcd945925a9.jpg?tr=tr:n-medium',
# ...

# %%
print(len(Restaurant_name))
print(len(Cuisine))
print(len(Ratings))
print(len(Image_URL))
# Out:
# 9
# 9
# 9
# 9

# %%
import pandas as pd

df = pd.DataFrame({'Title':Restaurant_name,'CuisineName':Cuisine,'Resto_Ratings':Ratings,'ImageURL': Image_URL})

df
# Out:
#                                                Title  \
# 0      Castle BarbequeConnaught Place, Central Delhi
# 1  Cafe KnoshThe Leela Ambience Convention Hotel,...
# 2  Castle's BarbequePacific Mall,Tagore Garden, W...
# 3    India GrillHilton Garden Inn,Saket, South Delhi
# 4  The Barbeque CompanyGardens Galleria,Sector 38...
# 5  Delhi BarbequeTaurus Sarovar Portico,Mahipalpu...
# 6  The Monarch - Bar Be Que VillageIndirapuram Ha...
# 7  The Barbeque TimesM2K Corporate Park,Sector 51...
# 8  Indian Grill RoomSuncity Business Tower,Golf C...
#
#                                          CuisineName Resto_Ratings  \
# 0                     Connaught Place, Central Delhi             4
# 1  The Leela Ambience Convention Hotel,Shahdara, ...           4.3
# 2             Pacific Mall,Tagore Garden, West Delhi           3.9
# 3               Hilton Garden Inn,Saket, South Delhi           3.9
# 4                 Gardens Galleria,Sector 38A, Noida           3.9
# ...
